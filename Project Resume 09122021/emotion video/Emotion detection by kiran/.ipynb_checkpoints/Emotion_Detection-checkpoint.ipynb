# %%
# lib's
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
    layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy'])

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
    zoom_range = 0.2, 
#     shear_range = 0.2, 
    horizontal_flip=True, 
    rescale = 1./255
    )

train_data = train_datagen.flow_from_directory(
    directory= "train/train/", 
    target_size=(224,224), 
    batch_size=32,
    )

train_data.class_indices
# Out:
# Found 350 images belonging to 7 classes.
# {'Angry': 0,
#  'Disguist': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(
    directory= "train/train/", 
    target_size=(224,224), 
    batch_size=32,
    )
# Out:
# Found 350 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
    """
    input  :- images array 
    output :- plots the images 
    """
    count = 0
    for im, l in zip(img_arr,label) :
        plt.imshow(im)
        plt.title(im.shape)
        plt.axis = False
        plt.show()

        count += 1
        if count == 10:
            break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_loss', min_delta= 0.01 , patience= 7, verbose= 1, mode='auto')
# 'val_accuracy'

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_loss', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [mc] # es,

# %%
hist = model.fit_generator(
    train_data, 
    steps_per_epoch= 10, 
    epochs= 100, 
    validation_data= val_data, 
    validation_steps= 8, 
    callbacks=call_back
)
# Out:
# c:\users\munge\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 10/10 [==============================] - 29s 3s/step - loss: 8.7647 - accuracy: 0.2490 - val_loss: 2.8224 - val_accuracy: 0.5586
#
# Epoch 00001: val_loss improved from inf to 2.82244, saving model to best_model.h5
# Epoch 2/100
# 10/10 [==============================] - 25s 3s/step - loss: 3.1573 - accuracy: 0.5657 - val_loss: 2.0476 - val_accuracy: 0.6719
#
# Epoch 00002: val_loss improved from 2.82244 to 2.04758, saving model to best_model.h5
# Epoch 3/100
# 10/10 [==============================] - 26s 3s/step - loss: 2.3047 - accuracy: 0.6493 - val_loss: 0.8921 - val_accuracy: 0.8320
#
# Epoch 00003: val_loss improved from 2.04758 to 0.89209, saving model to best_model.h5
# Epoch 4/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.9781 - accuracy: 0.8173 - val_loss: 0.2655 - val_accuracy: 0.9336
#
# Epoch 00004: val_loss improved from 0.89209 to 0.26547, saving model to best_model.h5
# Epoch 5/100
# 10/10 [==============================] - 24s 3s/step - loss: 0.3311 - accuracy: 0.9301 - val_loss: 0.2589 - val_accuracy: 0.9375
#
# Epoch 00005: val_loss improved from 0.26547 to 0.25889, saving model to best_model.h5
# Epoch 6/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.3128 - accuracy: 0.9276 - val_loss: 0.3122 - val_accuracy: 0.9141
#
# Epoch 00006: val_loss did not improve from 0.25889
# Epoch 7/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.2863 - accuracy: 0.9198 - val_loss: 0.2975 - val_accuracy: 0.9336
#
# Epoch 00007: val_loss did not improve from 0.25889
# Epoch 8/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.2043 - accuracy: 0.9391 - val_loss: 0.0130 - val_accuracy: 0.9922
#
# Epoch 00008: val_loss improved from 0.25889 to 0.01296, saving model to best_model.h5
# Epoch 9/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.1176 - accuracy: 0.9791 - val_loss: 0.0282 - val_accuracy: 0.9844
#
# Epoch 00009: val_loss did not improve from 0.01296
# Epoch 10/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0214 - accuracy: 0.9902 - val_loss: 0.0165 - val_accuracy: 0.9922
#
# Epoch 00010: val_loss did not improve from 0.01296
# Epoch 11/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0493 - accuracy: 0.9876 - val_loss: 0.0178 - val_accuracy: 0.9922
#
# Epoch 00011: val_loss did not improve from 0.01296
# Epoch 12/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.1085 - accuracy: 0.9846 - val_loss: 0.0373 - val_accuracy: 0.9844
#
# Epoch 00012: val_loss did not improve from 0.01296
# Epoch 13/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0684 - accuracy: 0.9762 - val_loss: 0.0012 - val_accuracy: 1.0000
#
# Epoch 00013: val_loss improved from 0.01296 to 0.00122, saving model to best_model.h5
# Epoch 14/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0354 - accuracy: 0.9935 - val_loss: 0.0046 - val_accuracy: 1.0000
#
# Epoch 00014: val_loss did not improve from 0.00122
# Epoch 15/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0132 - accuracy: 0.9969 - val_loss: 0.0038 - val_accuracy: 1.0000
#
# Epoch 00015: val_loss did not improve from 0.00122
# Epoch 16/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0447 - accuracy: 0.9849 - val_loss: 0.0012 - val_accuracy: 1.0000
#
# Epoch 00016: val_loss improved from 0.00122 to 0.00118, saving model to best_model.h5
# Epoch 17/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.1104 - accuracy: 0.9745 - val_loss: 0.0628 - val_accuracy: 0.9805
#
# Epoch 00017: val_loss did not improve from 0.00118
# Epoch 18/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0678 - accuracy: 0.9695 - val_loss: 0.0051 - val_accuracy: 0.9961
#
# Epoch 00018: val_loss did not improve from 0.00118
# Epoch 19/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0856 - accuracy: 0.9722 - val_loss: 7.7771e-04 - val_accuracy: 1.0000
#
# Epoch 00019: val_loss improved from 0.00118 to 0.00078, saving model to best_model.h5
# Epoch 20/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0405 - accuracy: 0.9798 - val_loss: 0.0281 - val_accuracy: 0.9922
#
# Epoch 00020: val_loss did not improve from 0.00078
# Epoch 21/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0157 - accuracy: 0.9924 - val_loss: 0.0701 - val_accuracy: 0.9844
#
# Epoch 00021: val_loss did not improve from 0.00078
# Epoch 22/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.2302 - accuracy: 0.9458 - val_loss: 0.0172 - val_accuracy: 0.9961
#
# Epoch 00022: val_loss did not improve from 0.00078
# Epoch 23/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0508 - accuracy: 0.9834 - val_loss: 0.0088 - val_accuracy: 0.9961
#
# Epoch 00023: val_loss did not improve from 0.00078
# Epoch 24/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0377 - accuracy: 0.9852 - val_loss: 0.0103 - val_accuracy: 0.9961
#
# Epoch 00024: val_loss did not improve from 0.00078
# Epoch 25/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0233 - accuracy: 0.9934 - val_loss: 7.1796e-04 - val_accuracy: 1.0000
#
# Epoch 00025: val_loss improved from 0.00078 to 0.00072, saving model to best_model.h5
# Epoch 26/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0121 - accuracy: 0.9973 - val_loss: 0.0040 - val_accuracy: 1.0000
#
# Epoch 00026: val_loss did not improve from 0.00072
# Epoch 27/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0734 - accuracy: 0.9891 - val_loss: 0.0111 - val_accuracy: 0.9961
#
# Epoch 00027: val_loss did not improve from 0.00072
# Epoch 28/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0668 - accuracy: 0.9885 - val_loss: 0.1553 - val_accuracy: 0.9766
#
# Epoch 00028: val_loss did not improve from 0.00072
# Epoch 29/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.1614 - accuracy: 0.9783 - val_loss: 0.0220 - val_accuracy: 0.9922
#
# Epoch 00029: val_loss did not improve from 0.00072
# Epoch 30/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0415 - accuracy: 0.9944 - val_loss: 0.0076 - val_accuracy: 0.9961
#
# Epoch 00030: val_loss did not improve from 0.00072
# Epoch 31/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0350 - accuracy: 0.9862 - val_loss: 6.0960e-05 - val_accuracy: 1.0000
#
# Epoch 00031: val_loss improved from 0.00072 to 0.00006, saving model to best_model.h5
# Epoch 32/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0055 - accuracy: 0.9953 - val_loss: 0.0064 - val_accuracy: 1.0000
#
# Epoch 00032: val_loss did not improve from 0.00006
# Epoch 33/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0715 - accuracy: 0.9785 - val_loss: 0.0010 - val_accuracy: 1.0000
#
# Epoch 00033: val_loss did not improve from 0.00006
# Epoch 34/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 8.1140e-04 - val_accuracy: 1.0000
#
# Epoch 00034: val_loss did not improve from 0.00006
# Epoch 35/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0422 - accuracy: 0.9826 - val_loss: 0.0025 - val_accuracy: 1.0000
#
# Epoch 00035: val_loss did not improve from 0.00006
# Epoch 36/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0043 - accuracy: 0.9962 - val_loss: 0.0056 - val_accuracy: 0.9961
#
# Epoch 00036: val_loss did not improve from 0.00006
# Epoch 37/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0294 - accuracy: 0.9919 - val_loss: 0.0056 - val_accuracy: 0.9961
#
# Epoch 00037: val_loss did not improve from 0.00006
# Epoch 38/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0267 - accuracy: 0.9924 - val_loss: 0.0073 - val_accuracy: 0.9961
#
# Epoch 00038: val_loss did not improve from 0.00006
# Epoch 39/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0252 - accuracy: 0.9842 - val_loss: 3.1287e-04 - val_accuracy: 1.0000
#
# Epoch 00039: val_loss did not improve from 0.00006
# Epoch 40/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 1.8297e-04 - val_accuracy: 1.0000
#
# Epoch 00040: val_loss did not improve from 0.00006
# Epoch 41/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
#
# Epoch 00041: val_loss did not improve from 0.00006
# Epoch 42/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0057 - accuracy: 0.9988 - val_loss: 2.4957e-04 - val_accuracy: 1.0000
#
# Epoch 00042: val_loss did not improve from 0.00006
# Epoch 43/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0047 - accuracy: 0.9979 - val_loss: 1.1278e-04 - val_accuracy: 1.0000
#
# Epoch 00043: val_loss did not improve from 0.00006
# Epoch 44/100
# 10/10 [==============================] - 30s 3s/step - loss: 1.5775e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
#
# Epoch 00044: val_loss did not improve from 0.00006
# Epoch 45/100
# 10/10 [==============================] - 25s 3s/step - loss: 5.6501e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 0.9961
#
# Epoch 00045: val_loss did not improve from 0.00006
# Epoch 46/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0143 - accuracy: 0.9956 - val_loss: 2.8775e-04 - val_accuracy: 1.0000
#
# Epoch 00046: val_loss did not improve from 0.00006
# Epoch 47/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0075 - accuracy: 0.9960 - val_loss: 0.0133 - val_accuracy: 0.9961
#
# Epoch 00047: val_loss did not improve from 0.00006
# Epoch 48/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0237 - accuracy: 0.9882 - val_loss: 0.0063 - val_accuracy: 0.9961
#
# Epoch 00048: val_loss did not improve from 0.00006
# Epoch 49/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0326 - accuracy: 0.9910 - val_loss: 6.2980e-04 - val_accuracy: 1.0000
#
# Epoch 00049: val_loss did not improve from 0.00006
# Epoch 50/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0793 - accuracy: 0.9667 - val_loss: 0.0091 - val_accuracy: 0.9961
#
# Epoch 00050: val_loss did not improve from 0.00006
# Epoch 51/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0094 - accuracy: 0.9933 - val_loss: 6.9327e-04 - val_accuracy: 1.0000
#
# Epoch 00051: val_loss did not improve from 0.00006
# Epoch 52/100
# 10/10 [==============================] - 25s 3s/step - loss: 2.7790e-04 - accuracy: 1.0000 - val_loss: 2.6335e-04 - val_accuracy: 1.0000
#
# Epoch 00052: val_loss did not improve from 0.00006
# Epoch 53/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 1.6929e-04 - val_accuracy: 1.0000
#
# Epoch 00053: val_loss did not improve from 0.00006
# Epoch 54/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0191 - val_accuracy: 0.9922
#
# Epoch 00054: val_loss did not improve from 0.00006
# Epoch 55/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0641 - accuracy: 0.9828 - val_loss: 0.0633 - val_accuracy: 0.9922
#
# Epoch 00055: val_loss did not improve from 0.00006
# Epoch 56/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0546 - accuracy: 0.9868 - val_loss: 0.0039 - val_accuracy: 0.9961
#
# Epoch 00056: val_loss did not improve from 0.00006
# Epoch 57/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0195 - accuracy: 0.9899 - val_loss: 0.0159 - val_accuracy: 0.9922
#
# Epoch 00057: val_loss did not improve from 0.00006
# Epoch 58/100
# 10/10 [==============================] - 30s 3s/step - loss: 6.7715e-04 - accuracy: 0.9994 - val_loss: 2.0077e-05 - val_accuracy: 1.0000
#
# Epoch 00058: val_loss improved from 0.00006 to 0.00002, saving model to best_model.h5
# Epoch 59/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0241 - accuracy: 0.9908 - val_loss: 0.0160 - val_accuracy: 0.9922
#
# Epoch 00059: val_loss did not improve from 0.00002
# Epoch 60/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0458 - accuracy: 0.9926 - val_loss: 0.0022 - val_accuracy: 1.0000
#
# Epoch 00060: val_loss did not improve from 0.00002
# Epoch 61/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0265 - accuracy: 0.9775 - val_loss: 0.0741 - val_accuracy: 0.9922
#
# Epoch 00061: val_loss did not improve from 0.00002
# Epoch 62/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0426 - accuracy: 0.9863 - val_loss: 0.0192 - val_accuracy: 0.9961
#
# Epoch 00062: val_loss did not improve from 0.00002
# Epoch 63/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0443 - accuracy: 0.9751 - val_loss: 0.0063 - val_accuracy: 0.9961
#
# Epoch 00063: val_loss did not improve from 0.00002
# Epoch 64/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0287 - accuracy: 0.9961 - val_loss: 0.0496 - val_accuracy: 0.9883
#
# Epoch 00064: val_loss did not improve from 0.00002
# Epoch 65/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0325 - accuracy: 0.9934 - val_loss: 0.0017 - val_accuracy: 1.0000
#
# Epoch 00065: val_loss did not improve from 0.00002
# Epoch 66/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0132 - accuracy: 0.9930 - val_loss: 0.0643 - val_accuracy: 0.9922
#
# Epoch 00066: val_loss did not improve from 0.00002
# Epoch 67/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0729 - accuracy: 0.9874 - val_loss: 0.0128 - val_accuracy: 0.9922
#
# Epoch 00067: val_loss did not improve from 0.00002
# Epoch 68/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0399 - accuracy: 0.9828 - val_loss: 0.0146 - val_accuracy: 0.9961
#
# Epoch 00068: val_loss did not improve from 0.00002
# Epoch 69/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0756 - accuracy: 0.9809 - val_loss: 0.1091 - val_accuracy: 0.9727
#
# Epoch 00069: val_loss did not improve from 0.00002
# Epoch 70/100
# 10/10 [==============================] - 24s 2s/step - loss: 0.0879 - accuracy: 0.9851 - val_loss: 0.0207 - val_accuracy: 0.9922
#
# Epoch 00070: val_loss did not improve from 0.00002
# Epoch 71/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0499 - accuracy: 0.9940 - val_loss: 0.0018 - val_accuracy: 1.0000
#
# Epoch 00071: val_loss did not improve from 0.00002
# Epoch 72/100
# 10/10 [==============================] - 33s 3s/step - loss: 0.0754 - accuracy: 0.9883 - val_loss: 0.0021 - val_accuracy: 1.0000
#
# Epoch 00072: val_loss did not improve from 0.00002
# Epoch 73/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 0.0081 - val_accuracy: 0.9961
#
# Epoch 00073: val_loss did not improve from 0.00002
# Epoch 74/100
# 10/10 [==============================] - 23s 2s/step - loss: 0.0324 - accuracy: 0.9898 - val_loss: 0.0015 - val_accuracy: 1.0000
#
# Epoch 00074: val_loss did not improve from 0.00002
# Epoch 75/100
# 10/10 [==============================] - 25s 3s/step - loss: 0.0172 - accuracy: 0.9922 - val_loss: 0.0122 - val_accuracy: 0.9922
#
# Epoch 00075: val_loss did not improve from 0.00002
# Epoch 76/100
# 10/10 [==============================] - 29s 3s/step - loss: 5.5749e-04 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 0.9922
#
# Epoch 00076: val_loss did not improve from 0.00002
# Epoch 77/100
# 10/10 [==============================] - 26s 3s/step - loss: 0.0759 - accuracy: 0.9915 - val_loss: 0.0076 - val_accuracy: 0.9961
#
# Epoch 00077: val_loss did not improve from 0.00002
# Epoch 78/100
# 10/10 [==============================] - 27s 3s/step - loss: 0.0463 - accuracy: 0.9859 - val_loss: 1.7964e-05 - val_accuracy: 1.0000
#
# Epoch 00078: val_loss improved from 0.00002 to 0.00002, saving model to best_model.h5
# Epoch 79/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0054 - accuracy: 0.9966 - val_loss: 0.0061 - val_accuracy: 0.9961
#
# Epoch 00079: val_loss did not improve from 0.00002
# Epoch 80/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0673 - accuracy: 0.9917 - val_loss: 0.0374 - val_accuracy: 0.9961
#
# Epoch 00080: val_loss did not improve from 0.00002
# Epoch 81/100
# 10/10 [==============================] - 24s 2s/step - loss: 0.0461 - accuracy: 0.9930 - val_loss: 0.0144 - val_accuracy: 0.9922
#
# Epoch 00081: val_loss did not improve from 0.00002
# Epoch 82/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0760 - accuracy: 0.9849 - val_loss: 0.0596 - val_accuracy: 0.9922
# Epoch 00082: val_loss did not improve from 0.00002
# Epoch 83/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.3002 - accuracy: 0.9661 - val_loss: 0.1768 - val_accuracy: 0.9609
#
# Epoch 00083: val_loss did not improve from 0.00002
# Epoch 84/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.2221 - accuracy: 0.9648 - val_loss: 0.0192 - val_accuracy: 0.9922
#
# Epoch 00084: val_loss did not improve from 0.00002
# Epoch 85/100
# 10/10 [==============================] - 35s 4s/step - loss: 0.1644 - accuracy: 0.9590 - val_loss: 0.2294 - val_accuracy: 0.9727
#
# Epoch 00085: val_loss did not improve from 0.00002
# Epoch 86/100
# 10/10 [==============================] - 33s 3s/step - loss: 0.1243 - accuracy: 0.9675 - val_loss: 0.1471 - val_accuracy: 0.9805
#
# Epoch 00086: val_loss did not improve from 0.00002
# Epoch 87/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.1958 - accuracy: 0.9700 - val_loss: 0.0217 - val_accuracy: 0.9922
#
# Epoch 00087: val_loss did not improve from 0.00002
# Epoch 88/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.2045 - accuracy: 0.9711 - val_loss: 0.0313 - val_accuracy: 0.9961
#
# Epoch 00088: val_loss did not improve from 0.00002
# Epoch 89/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2115 - accuracy: 0.9594 - val_loss: 0.0429 - val_accuracy: 0.9922
#
# Epoch 00089: val_loss did not improve from 0.00002
# Epoch 90/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.5072 - accuracy: 0.9370 - val_loss: 0.0957 - val_accuracy: 0.9766
#
# Epoch 00090: val_loss did not improve from 0.00002
# Epoch 91/100
# 10/10 [==============================] - 23s 2s/step - loss: 0.3752 - accuracy: 0.9673 - val_loss: 0.0431 - val_accuracy: 0.9922
#
# Epoch 00091: val_loss did not improve from 0.00002
# Epoch 92/100
# 10/10 [==============================] - 28s 3s/step - loss: 0.0136 - accuracy: 0.9944 - val_loss: 6.0383e-06 - val_accuracy: 1.0000
#
# Epoch 00092: val_loss improved from 0.00002 to 0.00001, saving model to best_model.h5
# Epoch 93/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0243 - accuracy: 0.9933 - val_loss: 0.0015 - val_accuracy: 1.0000
#
# Epoch 00093: val_loss did not improve from 0.00001
# Epoch 94/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.1188 - accuracy: 0.9887 - val_loss: 1.8850e-04 - val_accuracy: 1.0000
#
# Epoch 00094: val_loss did not improve from 0.00001
# Epoch 95/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.2204 - accuracy: 0.9797 - val_loss: 0.0692 - val_accuracy: 0.9922
#
# Epoch 00095: val_loss did not improve from 0.00001
# Epoch 96/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1080 - accuracy: 0.9846 - val_loss: 0.0826 - val_accuracy: 0.9766
#
# Epoch 00096: val_loss did not improve from 0.00001
# Epoch 97/100
# 10/10 [==============================] - 33s 3s/step - loss: 0.0314 - accuracy: 0.9910 - val_loss: 0.0014 - val_accuracy: 1.0000
#
# Epoch 00097: val_loss did not improve from 0.00001
# Epoch 98/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0443 - accuracy: 0.9958 - val_loss: 0.0012 - val_accuracy: 1.0000
#
# Epoch 00098: val_loss did not improve from 0.00001
# Epoch 99/100
# 10/10 [==============================] - 30s 3s/step - loss: 1.4818e-04 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9961
#
# Epoch 00099: val_loss did not improve from 0.00001
# Epoch 100/100
# 10/10 [==============================] - 29s 3s/step - loss: 8.1306e-06 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 0.9961
#
# Epoch 00100: val_loss did not improve from 0.00001

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))
op
# Out:
# {0: 'Angry',
#  1: 'Disguist',
#  2: 'Fear',
#  3: 'Happy',
#  4: 'Neutral',
#  5: 'Sad',
#  6: 'Surprise'}

# %%
# path for the image to see if it predics correct class

path = "new.jpg" # "mann.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
#  the image is of Angry
