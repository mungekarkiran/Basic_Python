# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
import cv2
import glob, os

# %%
# Basic augmentation with Keras
def augment_with_keras(image_path, save_dir='augmented_images'):
    """Basic image augmentation using Keras"""
    
    # Create the folder safely
    os.makedirs(save_dir, exist_ok=True)
    
    # Create ImageDataGenerator with various augmentation options
    datagen = ImageDataGenerator(
        rotation_range=10,          # Random rotation (0-40 degrees)
        width_shift_range=0.15,      # Horizontal shift
        # height_shift_range=0.15,     # Vertical shift
        # shear_range=0.2,            # Shear transformation
        zoom_range=0.2,             # Random zoom
        horizontal_flip=True,       # Horizontal flip
        # vertical_flip=True,         # Vertical flip
        brightness_range=[0.5, 1.5], # Brightness adjustment
        fill_mode='nearest'          # How to fill new pixels
    )
    
    # Load image
    img = tf.keras.preprocessing.image.load_img(image_path)
    x = tf.keras.preprocessing.image.img_to_array(img)
    x = x.reshape((1,) + x.shape)
    
    # Generate augmented images
    i = 0
    for batch in datagen.flow(x, batch_size=1, save_to_dir=save_dir, 
                              save_prefix='aug', save_format='jpeg'):
        i += 1
        if i >= 2:  # Generate 20 augmented images
            break
    
    # print(f"Generated {i} augmented images in '{save_dir}'")
    return datagen

# %%
for img_path in glob.glob(os.path.join('Dataset', 'Brain Tumor Meduloblastoma', 'Meduloblastoma', '*')):
    # print(img_path)
    augment_with_keras(img_path)
    # break
print('done')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 3
#       1 for img_path in glob.glob(os.path.join('Dataset', 'Brain Tumor Meduloblastoma', 'Meduloblastoma', '*')):
#       2     # print(img_path)
# ----> 3     augment_with_keras(img_path)
#       4     # break
#       5 print('done')
#
# Cell In[45], line 28, in augment_with_keras(image_path, save_dir)
#      24     x = x.reshape((1,) + x.shape)
#      25
#      26     # Generate augmented images
#      27     i = 0
# ---> 28     for batch in datagen.flow(x, batch_size=1, save_to_dir=save_dir,
#      29                               save_prefix='aug', save_format='jpeg'):
#      30         i += 1
#      31         if i >= 2:  # Generate 20 augmented images
#
# File ~\anaconda3\envs\bt_env\Lib\site-packages\keras\src\legacy\preprocessing\image.py:115, in Iterator.__next__(self)
#     112     index_array = next(self.index_generator)
#     113 # The transformation of images is not under thread lock
#     114 # so it can be done in parallel
# --> 115 return self._get_batches_of_transformed_samples(index_array)
#
# File ~\anaconda3\envs\bt_env\Lib\site-packages\keras\src\legacy\preprocessing\image.py:652, in NumpyArrayIterator._get_batches_of_transformed_samples(self, index_array)
#     650 x = self.x[j]
#     651 params = self.image_data_generator.get_random_transform(x.shape)
# --> 652 x = self.image_data_generator.apply_transform(
#     653     x.astype(self.dtype), params
#     654 )
#     655 x = self.image_data_generator.standardize(x)
#     656 batch_x[i] = x
#
# File ~\anaconda3\envs\bt_env\Lib\site-packages\keras\src\legacy\preprocessing\image.py:1411, in ImageDataGenerator.apply_transform(self, x, transform_parameters)
#    1408 img_col_axis = self.col_axis - 1
#    1409 img_channel_axis = self.channel_axis - 1
# -> 1411 x = apply_affine_transform(
#    1412     x,
#    1413     transform_parameters.get("theta", 0),
#    1414     transform_parameters.get("tx", 0),
#    1415     transform_parameters.get("ty", 0),
#    1416     transform_parameters.get("shear", 0),
#    1417     transform_parameters.get("zx", 1),
#    1418     transform_parameters.get("zy", 1),
#    1419     row_axis=img_row_axis,
#    1420     col_axis=img_col_axis,
#    1421     channel_axis=img_channel_axis,
#    1422     fill_mode=self.fill_mode,
#    1423     cval=self.cval,
#    1424     order=self.interpolation_order,
#    1425 )
#    1427 if transform_parameters.get("channel_shift_intensity") is not None:
#    1428     x = apply_channel_shift(
#    1429         x,
#    1430         transform_parameters["channel_shift_intensity"],
#    1431         img_channel_axis,
#    1432     )
#
# File ~\anaconda3\envs\bt_env\Lib\site-packages\keras\src\legacy\preprocessing\image.py:1872, in apply_affine_transform(x, theta, tx, ty, shear, zx, zy, row_axis, col_axis, channel_axis, fill_mode, cval, order)
#    1868 final_affine_matrix = transform_matrix[:2, :2]
#    1869 final_offset = transform_matrix[:2, 2]
#    1871 channel_images = [
# -> 1872     scipy.ndimage.interpolation.affine_transform(
#    1873         x_channel,
#    1874         final_affine_matrix,
#    1875         final_offset,
#    1876         order=order,
#    1877         mode=fill_mode,
#    1878         cval=cval,
#    1879     )
#    1880     for x_channel in x
#    1881 ]
#    1882 x = np.stack(channel_images, axis=0)
#    1883 x = np.rollaxis(x, 0, channel_axis + 1)
#
# File ~\anaconda3\envs\bt_env\Lib\site-packages\scipy\ndimage\_interpolation.py:652, in affine_transform(input, matrix, offset, output_shape, output, order, mode, cval, prefilter)
#     649     _nd_image.zoom_shift(filtered, matrix, offset/matrix, output, order,
#     650                          mode, cval, npad, False)
#     651 else:
# --> 652     _nd_image.geometric_transform(filtered, None, None, matrix, offset,
#     653                                   output, order, mode, cval, npad, None,
#     654                                   None)
#     655 return output
#
# KeyboardInterrupt:
