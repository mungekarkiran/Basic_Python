# %% [markdown]
# # HFA with Transformer_semenctics_features_extraction
# # Average Top-5 Accuracy: 78.09%
# # Time calculation

# %%
import os
import glob
import pandas as pd
import time
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]

# Index mapping
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to CSV file
csv_file_path = "prediction_results_Resnet_GLCM_AWA2_chimpanzee.csv"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Timing start
start_time = time.time()

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Timing end
end_time = time.time()
total_time = end_time - start_time
time_per_image = total_time / len(df)

print(f"Total images processed: {len(df)}")
print(f"Total processing time: {total_time:.4f} seconds")
print(f"Average time per image: {time_per_image:.4f} seconds")

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_chimpanzee_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Total images processed: 728
# Total processing time: 53.7162 seconds
# Average time per image: 0.0738 seconds
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_chimpanzee_with_Transfomer_similarity.csv'

# %% [markdown]
# #HFA with Transformer_semenctics_features_extraction#

# %% [markdown]
# # Average Top-5 Accuracy: 78.09% #

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = "prediction_results_Resnet_GLCM_AWA2_chimpanzee.csv"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_chimpanzee_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_chimpanzee_with_Transfomer_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_chimpanzee_with_Transfomer_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#   image_label  correct  total  top5_accuracy (%)
# 0  chimpanzee      711    728              97.66
#
# Average Top-5 Accuracy: 97.66%

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = "prediction_results_Resnet_GLCM_AWA2_giant_panda.csv"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_giant_panda_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_giant_panda_with_Transfomer_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_giant_panda_with_Transfomer_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#    image_label  correct  total  top5_accuracy (%)
# 0  giant panda      299    874              34.21
#
# Average Top-5 Accuracy: 34.21%

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = "prediction_results_Resnet_GLCM_AWA2_hippopotamus.csv"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_hippopotamus_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_hippopotamus_with_Transfomer_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_hippopotamus_with_Transfomer_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary_hippopotamus.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#     image_label  correct  total  top5_accuracy (%)
# 0  hippopotamus      669    684              97.81
#
# Average Top-5 Accuracy: 97.81%

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = "prediction_results_Resnet_GLCM_AWA2_humpback_whale.csv"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_humpback_whale_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_humpback_whale_with_Transfomer_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_humpback_whale_with_Transfomer_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary_Humpback_whale.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#       image_label  correct  total  top5_accuracy (%)
# 0  humpback whale      709    709              100.0
#
# Average Top-5 Accuracy: 100.00%

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = r"/content/prediction_results_Resnet_GLCM_AWA2_leopard"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_leopard_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_leopard_with_Transfomer_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_leopard_with_Transfomer_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary_leopard.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#   image_label  correct  total  top5_accuracy (%)
# 0     leopard      720    720              100.0
#
# Average Top-5 Accuracy: 100.00%

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = "prediction_results_Resnet_GLCM_AWA2_percian_cat.csv"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_percian_cat_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_percian_cat_with_Transfomer_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_percian_cat_with_Transfomer_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#    image_label  correct  total  top5_accuracy (%)
# 0  persian cat      688    747               92.1
#
# Average Top-5 Accuracy: 92.10%

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = "prediction_results_Resnet_GLCM_AWA2_pig.csv"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_pig_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_pig_with_Transfomer_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_pig_with_Transfomer_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary_pig.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#   image_label  correct  total  top5_accuracy (%)
# 0         pig      521    713              73.07
#
# Average Top-5 Accuracy: 73.07%

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = r"/content/prediction_results_Resnet_GLCM_AWA2_raccoon"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_raccoon_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_raccoon_with_Transfomer_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_raccoon_with_Transfomer_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary_raccoon.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#   image_label  correct  total  top5_accuracy (%)
# 0     raccoon      446    512              87.11
#
# Average Top-5 Accuracy: 87.11%

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = r"/content/prediction_results_Resnet_GLCM_AWA2_rat"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_rat_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_rat_with_Transfomer_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_rat_with_Transfomer_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary_rat.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#   image_label  correct  total  top5_accuracy (%)
# 0         rat      277    310              89.35
#
# Average Top-5 Accuracy: 89.35%

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = r"/content/prediction_results_Resnet_GLCM_AWA2_seal"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_seal_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_seal_with_Transfomer_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_seal_with_Transfomer_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary_seal.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#   image_label  correct  total  top5_accuracy (%)
# 0        seal       95    988               9.62
#
# Average Top-5 Accuracy: 9.62%

# %% [markdown]
# #HFA with Transformer_semenctics_features_extraction
# # Modified_corpus #
# #Average Top-5 Accuracy: %

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
# image_class = [
#     "chimpanzee",
#     "giant panda",
#     "hippopotamus",
#     "humpback whale",
#     "leopard",
#     "persian cat",
#     "pig",
#     "raccoon",
#     "rat",
#     "seal"
# ]


image_class =["polar bear", "blue whale", "bobcat", "cow", "dolphin", "gorilla", "killer whale", "lion",
    "monkey", "mouse",
    "ox",
    "rabbit",
    "rhinoceros",
    "siamese cat",
    "skunk",
    "squirrel",
    "tiger",#
    "walrus",
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"]

# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = r"/content/prediction_results_Resnet_GLCM_AWA2_seal"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_seal_1_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_seal_1_with_Transfomer_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_seal_1_with_Transfomer_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary_seal_1.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#   image_label  correct  total  top5_accuracy (%)
# 0        seal        0    988                0.0
#
# Average Top-5 Accuracy: 0.00%

# %% [markdown]
# #HFA with Transformer_semenctics_features_extraction#
# #modified corpus                          #TOP-1 Accuarcy

# %%
import os

for root, dirs, files in os.walk('/content'):
    if 'prediction_results_Resnet_GLCM_AWA2_chimpanzee_with_Transformer_similarity.csv' in files:
        print(os.path.join(root, 'prediction_results_Resnet_GLCM_AWA2_chimpanzee_with_Transformer_similarity.csv'))

# %%
# !ls /content/drive/MyDrive/HFA_transfomer_result
# Out:
# ls: cannot access '/content/drive/MyDrive/HFA_transfomer_result': No such file or directory

# %%
import pandas as pd
import ast
import glob
import os

# Correct path — case-sensitive
import glob
csv_files = glob.glob("/content/sample_data/HFA_transfomer_result/*.csv")
print(csv_files)


if not csv_files:
    print("No CSV files found. Check the path.")
else:
    print(f"Found {len(csv_files)} files.")

all_results = []

def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]
    except:
        return []

for file in csv_files:
    df = pd.read_csv(file)

    if 'image_label' not in df.columns or 'top5_similar_labels_with_scores' not in df.columns:
        print(f"Skipping {file} — missing required columns.")
        continue

    df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()
    df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)
    df['top1_hit'] = df.apply(lambda row: row['image_label'] == row['top_5_predicted'][0] if row['top_5_predicted'] else False, axis=1)

    accuracy_per_class = df.groupby('image_label')['top1_hit'].agg(['sum', 'count']).reset_index()
    accuracy_per_class['top1_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
    accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

    avg_accuracy = round(accuracy_per_class['top1_accuracy (%)'].mean(), 2)

    all_results.append({
        "file": os.path.basename(file),
        "average_top1_accuracy (%)": avg_accuracy
    })

    out_name = os.path.splitext(file)[0] + "_top1_accuracy.csv"
    accuracy_per_class.to_csv(out_name, index=False)

summary_df = pd.DataFrame(all_results)
summary_df.to_csv("top1_accuracy_summary_AWA2.csv", index=False)

print(summary_df)
# Out:
# ['/content/sample_data/HFA_transfomer_result/prediction_results_Resnet_GLCM_AWA2_raccoon_with_Transfomer_similarity.csv', '/content/sample_data/HFA_transfomer_result/prediction_results_Resnet_GLCM_AWA2_chimpanzee_with_Transfomer_similarity.csv', '/content/sample_data/HFA_transfomer_result/prediction_results_Resnet_GLCM_AWA2_seal_with_Transfomer_similarity.csv', '/content/sample_data/HFA_transfomer_result/prediction_results_Resnet_GLCM_AWA2_leopard_with_Transfomer_similarity.csv', '/content/sample_data/HFA_transfomer_result/prediction_results_Resnet_GLCM_AWA2_pig_with_Transfomer_similarity.csv', '/content/sample_data/HFA_transfomer_result/prediction_results_Resnet_GLCM_AWA2_giant_panda_with_Transfomer_similarity.csv', '/content/sample_data/HFA_transfomer_result/prediction_results_Resnet_GLCM_AWA2_percian_cat_with_Transfomer_similarity.csv', '/content/sample_data/HFA_transfomer_result/prediction_results_Resnet_GLCM_AWA2_rat_with_Transfomer_similarity.csv', '/content/sample_data/HFA_transfomer_result/prediction_results_Resnet_GLCM_AWA2_humpback_whale_with_Transfomer_similarity.csv', '/content/sample_data/HFA_transfomer_result/prediction_results_Resnet_GLCM_AWA2_hippopotamus_with_Transfomer_similarity.csv']
# Found 10 files.
#                                                 file  \
# 0  prediction_results_Resnet_GLCM_AWA2_raccoon_wi...
# 1  prediction_results_Resnet_GLCM_AWA2_chimpanzee...
# 2  prediction_results_Resnet_GLCM_AWA2_seal_with_...
# 3  prediction_results_Resnet_GLCM_AWA2_leopard_wi...
# 4  prediction_results_Resnet_GLCM_AWA2_pig_with_T...
# 5  prediction_results_Resnet_GLCM_AWA2_giant_pand...
# 6  prediction_results_Resnet_GLCM_AWA2_percian_ca...
# 7  prediction_results_Resnet_GLCM_AWA2_rat_with_T...
# 8  prediction_results_Resnet_GLCM_AWA2_humpback_w...
# 9  prediction_results_Resnet_GLCM_AWA2_hippopotam...
#
#    average_top1_accuracy (%)
# 0                      18.95
# 1                      92.17
# 2                       0.00
# 3                      12.92
# 4                      42.08
# 5                       0.00
# 6                      88.22
# 7                      86.77
# 8                     100.00
# 9                      46.20

# %% [markdown]
# # Result top -1 accuarcy is : 48.73 % #

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-mpnet-base-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = "prediction_results_Resnet_GLCM_AWA2_chimpanzee.csv"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_chimpanzee_with_Transfomer_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")

# %% [markdown]
# # Final Autoencoder for transformer semntics model#

# %%
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import normalize
from scipy.spatial.distance import cosine
import numpy as np

# Step 1: Define your custom class labels
animal_labels = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]

#Training Classes (Seen)
# animal_labels = [
#     "polar bear", "blue whale", "bobcat", "cow", "dolphin", "gorilla", "killer whale", "lion",
#     "monkey", "mouse",
#     "ox",
#     "rabbit",
#     "rhinoceros",
#     "siamese cat",
#     "skunk",
#     "squirrel",
#     "tiger",#
#     "walrus",
#     "chimpanzee",
#     "giant panda",
#     "hippopotamus",
#     "humpback whale",
#     "leopard",
#     "persian cat",
#     "pig",
#     "raccoon",
#     "rat",
#     "seal"
# ]


animal_labels = list(dict.fromkeys(animal_labels))

# Step 2: Load transformer and encode
# transformer_model = SentenceTransformer('all-MiniLM-L6-v2')
transformer_model = SentenceTransformer('all-mpnet-base-v2')
animal_embeddings_768d = transformer_model.encode(animal_labels, convert_to_numpy=True)

# Step 3: Normalize the 384-d vectors
animal_embeddings_normalized = normalize(animal_embeddings_768d, axis=1)

# Step 4: Build index-to-vector mapping
label_index_to_vector = {
    idx: animal_embeddings_normalized[idx]
    for idx in range(len(animal_labels))
}
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from keras.models import Model
from keras.layers import Input, Dense, Dropout

def tune_autoencoder(input_dim, latent_dim):
    # Input layer
    input_layer = Input(shape=(input_dim,))

    # Encoder
    encoded = Dense(64, activation='relu')(input_layer)
    encoded = Dropout(0.3)(encoded)  # Dropout added here
    encoded = Dense(32, activation='relu')(encoded)
    encoded = Dense(latent_dim, activation='relu')(encoded)

    # Decoder
    decoded = Dense(32, activation='relu')(encoded)
    decoded = Dropout(0.3)(decoded)  # Dropout added here
    decoded = Dense(64, activation='relu')(decoded)
    decoded = Dense(input_dim, activation='sigmoid')(decoded)

    # Autoencoder model
    autoencoder = Model(input_layer, decoded)

    # Encoder model
    encoder = Model(input_layer, encoded)

    # Compile the autoencoder
    autoencoder.compile(optimizer='adam', loss='mse')

    return encoder, autoencoder

# %%
encoder, autoencoder = tune_autoencoder(384, 16)
print("encoder summary : ")
encoder.summary()
print("autoencoder summary : ")
autoencoder.summary()
# Out:
# encoder summary :
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 384)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,248 (106.44 KB)
#  Trainable params: 27,248 (106.44 KB)
#  Non-trainable params: 0 (0.00 B)
# autoencoder summary :
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 384)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 384)            │        24,960 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,864 (214.31 KB)
#  Trainable params: 54,864 (214.31 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
 # Assume animal_embeddings_normalized is your training input
encoder, autoencoder = tune_autoencoder(input_dim=768, latent_dim=16)  # adjust dimensions as needed

autoencoder.fit(
    animal_embeddings_normalized,
    animal_embeddings_normalized,
    epochs=500,
    batch_size=32,
    shuffle=True,
    validation_split=0.1
    # callbacks=[early_stopping]
)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.2516 - val_loss: 0.2513
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.2512 - val_loss: 0.2510
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.2508 - val_loss: 0.2506
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.2504 - val_loss: 0.2502
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.2499 - val_loss: 0.2498
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 0.2492 - val_loss: 0.2493
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.2485 - val_loss: 0.2486
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.2474 - val_loss: 0.2479
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.2463 - val_loss: 0.2470
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.2448 - val_loss: 0.2459
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.2430 - val_loss: 0.2447
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.2405 - val_loss: 0.2431
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.2388 - val_loss: 0.2413
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.2352 - val_loss: 0.2391
# Epoch 15/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.2314 - val_loss: 0.2364
# Epoch 16/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.2252 - val_loss: 0.2333
# Epoch 17/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.2201 - val_loss: 0.2296
# Epoch 18/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.2142 - val_loss: 0.2254
# Epoch 19/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.2078 - val_loss: 0.2204
# Epoch 20/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.1977 - val_loss: 0.2146
# Epoch 21/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.1918 - val_loss: 0.2079
# Epoch 22/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.1804 - val_loss: 0.2003
# Epoch 23/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.1701 - val_loss: 0.1917
# Epoch 24/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.1671 - val_loss: 0.1821
# Epoch 25/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - loss: 0.1461 - val_loss: 0.1714
# Epoch 26/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step - loss: 0.1356 - val_loss: 0.1597
# Epoch 27/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.1200 - val_loss: 0.1469
# Epoch 28/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.1048 - val_loss: 0.1333
# Epoch 29/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - loss: 0.0874 - val_loss: 0.1190
# Epoch 30/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 0.0731 - val_loss: 0.1044
# Epoch 31/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 0.0476 - val_loss: 0.0898
# Epoch 32/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0611 - val_loss: 0.0755
# Epoch 33/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0336 - val_loss: 0.0622
# Epoch 34/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0242 - val_loss: 0.0501
# Epoch 35/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0217 - val_loss: 0.0396
# Epoch 36/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0103 - val_loss: 0.0308
# Epoch 37/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0105 - val_loss: 0.0237
# Epoch 38/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.0048 - val_loss: 0.0180
# Epoch 39/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0054 - val_loss: 0.0137
# Epoch 40/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0078 - val_loss: 0.0104
# Epoch 41/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0028 - val_loss: 0.0080
# Epoch 42/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0028 - val_loss: 0.0062
# Epoch 43/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0018 - val_loss: 0.0049
# Epoch 44/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 45/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 46/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 47/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 48/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 49/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 50/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 51/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 52/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 53/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 54/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 55/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 56/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 57/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 58/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 59/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 60/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 61/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 62/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 63/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 64/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 65/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 66/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 67/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 68/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 69/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 70/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 71/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 72/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 73/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 74/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 75/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 76/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 77/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 78/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 79/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 80/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 81/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 82/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 83/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 84/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 85/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 86/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 87/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 88/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 89/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 90/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 91/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 92/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 93/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 94/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 95/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 96/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 97/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 98/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 99/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 100/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 101/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 102/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 103/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 104/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 105/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 106/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 721ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 107/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 108/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 109/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 110/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 111/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 112/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 113/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 114/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 115/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 116/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 117/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 118/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 119/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 120/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 121/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 122/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 123/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 124/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 125/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 126/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 127/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 128/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 129/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 130/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 131/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 132/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 133/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 134/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 758ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 135/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 136/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 796ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 137/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 882ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 138/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 139/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 140/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 141/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 142/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 143/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 144/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 145/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 146/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 147/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 148/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 149/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 150/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 151/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 152/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 153/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 154/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 155/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 156/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 157/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 158/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 159/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 160/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 161/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 162/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 163/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 164/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 165/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 166/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 167/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 168/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 169/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 170/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 171/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 172/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 173/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 174/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 682ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 175/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 176/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 177/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 178/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 179/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 180/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 181/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 182/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 183/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 184/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 185/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 186/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 187/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 188/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 189/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 190/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 191/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 788ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 192/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 193/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 194/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 195/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 685ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 196/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 197/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 198/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 199/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 200/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 201/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 202/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 203/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 204/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 205/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 206/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 207/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 208/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 209/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 210/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 211/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 212/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 213/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 214/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 215/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 216/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 217/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 218/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 219/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 220/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 221/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 222/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 223/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 224/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 225/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 226/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 227/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 228/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 229/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 230/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 231/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 232/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 233/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 234/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 235/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 236/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 237/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 238/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 239/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 240/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 241/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 242/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 243/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 244/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 245/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 246/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 247/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 248/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 249/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 250/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 251/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 252/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 253/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 254/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 255/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 256/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 257/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 258/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 259/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 260/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 261/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 262/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 263/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 264/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 265/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 266/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 267/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 268/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 269/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 270/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 271/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 272/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 273/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 274/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 275/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 276/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 277/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 278/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 279/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 280/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 281/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 282/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 283/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 284/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 285/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 286/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 287/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 288/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 289/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 290/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 291/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 292/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 293/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 294/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 295/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 296/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 297/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 298/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 299/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 300/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 301/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 302/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 303/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 304/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 305/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 306/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 307/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 308/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 309/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 310/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 311/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 312/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 313/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 314/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 315/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 316/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 317/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 318/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 319/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 320/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 321/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 322/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 323/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 324/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 325/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 326/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 327/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 328/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 329/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 330/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 331/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 332/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 333/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 334/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 335/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 336/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 337/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 338/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 339/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 340/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 341/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 342/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 343/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 344/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 345/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 346/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 347/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 348/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 349/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 350/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 351/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 352/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 353/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 354/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 355/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 356/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 357/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 358/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 359/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 360/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 361/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 362/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 363/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 364/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 365/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 366/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 367/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 368/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 369/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 370/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 371/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 372/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 373/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 374/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 375/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 376/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 377/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 378/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 379/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 380/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 381/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 382/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 383/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 384/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 385/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 386/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 387/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 388/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 389/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 390/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 391/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 392/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 393/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 394/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 395/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 396/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 397/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 398/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 399/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 400/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 401/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 402/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 403/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 404/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 405/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 406/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 407/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 408/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 409/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 410/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 411/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 412/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 413/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 414/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 415/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 416/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 417/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 418/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 419/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 420/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 421/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 422/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 423/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 424/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 425/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 426/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 427/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 428/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 429/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 430/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 431/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 432/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 433/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 434/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 435/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 436/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 437/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 438/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 439/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 440/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 441/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 442/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 443/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 444/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 445/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 446/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 447/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 448/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 449/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 450/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 451/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 452/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 453/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 454/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 455/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 456/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 457/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 458/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 459/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 460/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 461/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 462/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 463/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 464/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 465/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 466/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 467/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 468/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 469/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 470/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 471/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 472/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 473/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 474/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 475/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 476/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 477/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 478/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 479/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 480/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 481/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 482/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 483/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 484/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 485/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 486/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 487/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 488/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 489/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 490/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 491/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 492/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 493/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 494/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 495/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 496/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 497/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 498/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 499/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 500/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0012 - val_loss: 0.0015

# %%
import matplotlib.pyplot as plt

# Define latent dimension if not already defined
latent_dim = 16  # Change to the actual value you used

# Plot training and validation loss
plt.plot(autoencoder.history.history['loss'], color='blue')
plt.plot(autoencoder.history.history['val_loss'], color='orange')
plt.title(f'Model Loss – Latent Dim {latent_dim}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

# Save and display
plt.savefig("autoencoder_loss_plot.png", bbox_inches='tight')
plt.show()

# %%
import numpy as np
from sentence_transformers import SentenceTransformer

# Load transformer
model = SentenceTransformer('all-mpnet-base-v2')

# Unseen classes
unseen_classes = [
    "chimpanzee", "giant panda", "hippopotamus", "humpback whale", "leopard",
    "persian cat", "pig", "raccoon", "rat", "seal"
]

# Get transformer embeddings
unseen_embeddings = model.encode(unseen_classes)

# Normalize if needed
unseen_embeddings_norm = unseen_embeddings / np.linalg.norm(unseen_embeddings, axis=1, keepdims=True)

# Pass through trained encoder
compressed_unseen = encoder.predict(unseen_embeddings_norm)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# Load your predictions CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_chimpanzee")
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

similar_wds = []
for _, row in df.iterrows():
    # Transformer embedding for predicted label
    pred_emb = model.encode(row['cleaned_pred_label'])
    pred_emb = pred_emb / np.linalg.norm(pred_emb)  # normalize

    # Compress via autoencoder
    pred_compressed = encoder.predict(pred_emb.reshape(1, -1))

    # Cosine similarity in compressed space
    cos_scores = cosine_similarity(pred_compressed, compressed_unseen)[0]

    # Top-5 results
    top5_idx = np.argsort(cos_scores)[::-1][:5]
    top5_labels = [unseen_classes[i] for i in top5_idx]
    top5_scores = [round(cos_scores[i] * 100, 2) for i in top5_idx]

    similar_wds.append((top5_labels, top5_scores))

# Add to dataframe
df['top5_similar_labels_with_scores'] = similar_wds
df.to_csv("with_autoencoder_similarity_chimpaznzee.csv", index=False)
print("✅ Saved results with Autoencoder similarity")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Saved results with Autoencoder similarity

# %%
import pandas as pd
import re

def normalize_label(label):
    """Lowercase, replace underscores, strip spaces, collapse multiple spaces."""
    return re.sub(r'\s+', ' ', str(label)).replace("_", " ").strip().lower()

# Load CSV
df = pd.read_csv("with_autoencoder_similarity_seal.csv")

# Clean actual labels
df['image_label'] = df['image_label'].apply(normalize_label)

# Extract only the label list before the comma
def extract_labels(top5_str):
    try:
        # Get the part before the first closing bracket of labels
        match = re.search(r"\(\s*(\[[^\]]*\])", top5_str)
        if match:
            labels_str = match.group(1)
            labels_list = eval(labels_str)  # safe enough because it's just list of strings
            return [normalize_label(lbl) for lbl in labels_list]
        else:
            return []
    except Exception as e:
        print("Error extracting labels from:", top5_str, e)
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Check if match works now
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Accuracy per class
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)
print(f"\n✅ Average Top-5 Accuracy: {average_top5_accuracy:.2f}%")
# Out:
# Top-5 Accuracy per Class:
#   image_label  correct  total  top5_accuracy (%)
# 0        seal      148    988              14.98
#
# ✅ Average Top-5 Accuracy: 14.98%

# %% [markdown]
# # HFA with Transformer with autoecoder #
# # Timing calculation #

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import time

# ------------------------------
# Load models
# ------------------------------
model = SentenceTransformer('all-mpnet-base-v2')  # Transformer model
# encoder = ...  # Your trained autoencoder encoder model
# unseen_classes = [...]  # List of unseen class names
# compressed_unseen = encoder.predict(unseen_class_embeddings) -> We'll compute this below

# ------------------------------
# Load CSV
# ------------------------------
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_chimpanzee.csv")
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# ------------------------------
# Timing start
# ------------------------------
start_time = time.time()

# 1️⃣ Encode unseen class labels once
unseen_class_embeddings = model.encode(unseen_classes, normalize_embeddings=True)
compressed_unseen = encoder.predict(unseen_class_embeddings)

# 2️⃣ Encode predicted labels once
pred_embeddings = model.encode(df['cleaned_pred_label'].tolist(), normalize_embeddings=True)
compressed_preds = encoder.predict(pred_embeddings)

# 3️⃣ Compute cosine similarity in compressed space for all images at once
cos_scores_matrix = cosine_similarity(compressed_preds, compressed_unseen)

# 4️⃣ Extract top-5 results for each image
similar_wds = []
for scores in cos_scores_matrix:
    top5_idx = np.argsort(scores)[::-1][:5]
    top5_labels = [unseen_classes[i] for i in top5_idx]
    top5_scores = [round(scores[i] * 100, 2) for i in top5_idx]
    similar_wds.append((top5_labels, top5_scores))

# ------------------------------
# Timing end
# ------------------------------
end_time = time.time()
total_time = end_time - start_time
time_per_image = total_time / len(df)

print(f"Total images processed: {len(df)}")
print(f"Total processing time: {total_time:.4f} seconds")
print(f"Average time per image: {time_per_image:.4f} seconds")

# ------------------------------
# Save results
# ------------------------------
df['top5_similar_labels_with_scores'] = similar_wds
df.to_csv("with_autoencoder_similarity_chimpanzee_fast.csv", index=False)
print("✅ Saved results with Autoencoder similarity (optimized)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Total images processed: 728
# Total processing time: 15.0264 seconds
# Average time per image: 0.0206 seconds
# ✅ Saved results with Autoencoder similarity (optimized)

# %%
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import normalize
from scipy.spatial.distance import cosine
import numpy as np

# Step 1: Define your custom class labels
# animal_labels =# Test Classes (Unseen)
# test_classes = [
#     "chimpanzee",
#     "giant panda",
#     "hippopotamus",
#     "humpback whale",
#     "leopard",
#     "persian cat",
#     "pig",
#     "raccoon",
#     "rat",
#     "seal"
# ]

#Training Classes (Seen)
animal_labels = [
    "polar bear", "blue whale", "bobcat", "cow", "dolphin", "gorilla", "killer whale", "lion",
    "monkey", "mouse",
    "ox",
    "rabbit",
    "rhinoceros",
    "siamese cat",
    "skunk",
    "squirrel",
    "tiger",#
    "walrus",
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


animal_labels = list(dict.fromkeys(animal_labels))

# Step 2: Load transformer and encode
# transformer_model = SentenceTransformer('all-MiniLM-L6-v2')
transformer_model = SentenceTransformer('all-MiniLM-L6-v2')
animal_embeddings_384d = transformer_model.encode(animal_labels, convert_to_numpy=True)

# Step 3: Normalize the 384-d vectors
animal_embeddings_normalized = normalize(animal_embeddings_384d, axis=1)

# Step 4: Build index-to-vector mapping
label_index_to_vector = {
    idx: animal_embeddings_normalized[idx]
    for idx in range(len(animal_labels))
}
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
def get_top_similar_animals(reference_idx, vector_dict, top_n=15):
    reference_vec = vector_dict[reference_idx]
    similarity_scores = []

    for idx, vec in vector_dict.items():
        if idx != reference_idx:
            sim = 1 - cosine(reference_vec, vec)
            similarity_scores.append((idx, sim))

    similarity_scores.sort(key=lambda x: x[1], reverse=True)
    return similarity_scores[:top_n]

# Example: Find top 10 most similar to 'blue whale' (index 0)
top_similar = get_top_similar_animals(2, label_index_to_vector, top_n=20)

print(f"Most similar to '{animal_labels[2]}':")
for idx, score in top_similar:
    print(f"  {animal_labels[idx]} - similarity: {score:.4f}")
# Out:
# Most similar to 'bobcat':
#   rabbit - similarity: 0.4130
#   polar bear - similarity: 0.4103
#   lion - similarity: 0.3923
#   leopard - similarity: 0.3867
#   pig - similarity: 0.3773
#   humpback whale - similarity: 0.3654
#   dolphin - similarity: 0.3517
#   cow - similarity: 0.3480
#   monkey - similarity: 0.3437
#   walrus - similarity: 0.3413
#   blue whale - similarity: 0.3359
#   tiger - similarity: 0.3221
#   killer whale - similarity: 0.3208
#   gorilla - similarity: 0.3105
#   squirrel - similarity: 0.3044
#   rat - similarity: 0.2990
#   persian cat - similarity: 0.2898
#   giant panda - similarity: 0.2863
#   chimpanzee - similarity: 0.2735
#   siamese cat - similarity: 0.2655

# %% [markdown]
# #SciBERT model from Hugging Face#

# %%
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import normalize
from scipy.spatial.distance import cosine
import numpy as np

# Step 1: Define your custom class labels
animal_labels = [
    "polar bear", "blue whale", "bobcat", "cow", "dolphin", "gorilla", "killer whale", "lion",
    "monkey", "mouse",
    "ox",
    "rabbit",
    "rhinoceros",
    "siamese cat",
    "skunk",
    "squirrel",
    "tiger",
    "walrus",
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# animal_labels = [
#     "chimpanzee",
#     "giant panda",
#     "hippopotamus",
#     "humpback whale",
#     "leopard",
#     "persian cat",
#     "pig",
#     "raccoon",
#     "rat",
#     "seal"
# ]
# Remove duplicates if any
animal_labels = list(dict.fromkeys(animal_labels))

# Step 2: Load SciBERT model from Hugging Face
# This variant is fine-tuned for sentence similarity tasks
transformer_model = SentenceTransformer('pritamdeka/S-Scibert-snli-multinli-stsb')

# Step 3: Encode labels into 768-d embeddings
animal_embeddings = transformer_model.encode(animal_labels, convert_to_numpy=True)

# Step 4: Normalize the embeddings
animal_embeddings_normalized = normalize(animal_embeddings, axis=1)

# Step 5: Build index-to-vector mapping
label_index_to_vector = {
    idx: animal_embeddings_normalized[idx]
    for idx in range(len(animal_labels))
}

# Function to get top-N most similar animals
def get_top_similar_animals(reference_idx, vector_dict, top_n=15):
    reference_vec = vector_dict[reference_idx]
    similarity_scores = []

    for idx, vec in vector_dict.items():
        if idx != reference_idx:
            sim = 1 - cosine(reference_vec, vec)
            similarity_scores.append((idx, sim))

    similarity_scores.sort(key=lambda x: x[1], reverse=True)
    return similarity_scores[:top_n]

# Example: Find top 20 most similar to 'bobcat' (index 2)
top_similar = get_top_similar_animals(16, label_index_to_vector, top_n=20)

print(f"Most similar to '{animal_labels[16]}':")
for idx, score in top_similar:
    print(f"  {animal_labels[idx]} - similarity: {score:.4f}")
# Out:
# Most similar to 'tiger':
#   gorilla - similarity: 0.2303
#   ox - similarity: 0.2031
#   dolphin - similarity: 0.1927
#   lion - similarity: 0.1835
#   monkey - similarity: 0.1636
#   rat - similarity: 0.1564
#   persian cat - similarity: 0.1427
#   cow - similarity: 0.1409
#   chimpanzee - similarity: 0.1313
#   seal - similarity: 0.1018
#   squirrel - similarity: 0.1009
#   blue whale - similarity: 0.0880
#   pig - similarity: 0.0850
#   walrus - similarity: 0.0831
#   hippopotamus - similarity: 0.0824
#   siamese cat - similarity: 0.0823
#   leopard - similarity: 0.0775
#   skunk - similarity: 0.0637
#   polar bear - similarity: 0.0525
#   mouse - similarity: 0.0466

# %%
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import normalize
from scipy.spatial.distance import cosine
import numpy as np

# Step 1: Define your fixed animal label set
animal_labels = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]

# Step 2: Load SciBERT model
transformer_model = SentenceTransformer('pritamdeka/S-Scibert-snli-multinli-stsb')

# Step 3: Encode & normalize the known labels
animal_embeddings = transformer_model.encode(animal_labels, convert_to_numpy=True)
animal_embeddings_normalized = normalize(animal_embeddings, axis=1)

label_index_to_vector = {idx: animal_embeddings_normalized[idx] for idx in range(len(animal_labels))}

# Function to get similarity with ANY query term
def get_top_similar_animals(query, vector_dict, labels, model, top_n=5):
    # Encode & normalize the query
    query_vec = model.encode([query], convert_to_numpy=True)
    query_vec = normalize(query_vec, axis=1)[0]

    # Calculate similarity with all animals
    similarity_scores = []
    for idx, vec in vector_dict.items():
        sim = 1 - cosine(query_vec, vec)
        similarity_scores.append((labels[idx], sim))

    # Sort and return top N
    similarity_scores.sort(key=lambda x: x[1], reverse=True)
    return query, similarity_scores[:top_n]

# Example: query term not in the list
ref_label, top_similar = get_top_similar_animals("tiger", label_index_to_vector, animal_labels, transformer_model, top_n=10)

print(f"Most similar to '{ref_label}':")
for label, score in top_similar:
    print(f"  {label} - similarity: {score:.4f}")
# Out:
# Most similar to 'tiger':
#   rat - similarity: 0.1564
#   persian cat - similarity: 0.1427
#   chimpanzee - similarity: 0.1313
#   seal - similarity: 0.1018
#   pig - similarity: 0.0850
#   hippopotamus - similarity: 0.0824
#   leopard - similarity: 0.0775
#   giant panda - similarity: 0.0423
#   raccoon - similarity: 0.0181
#   humpback whale - similarity: -0.0229

# %% [markdown]
# # To find the similarity using transformer by uploading csv#

# %%
import pandas as pd

# Load your CSV file (replace with your actual path)
df = pd.read_csv("prediction_results_10images_per_class.csv")

# Clean the pred_image_label column: remove underscores
df['cleaned_label'] = df['pred_image_label'].str.replace("_", " ")

# Encode cleaned labels using the same transformer
pred_embeddings = transformer_model.encode(df['cleaned_label'].tolist(), convert_to_numpy=True)
pred_embeddings_normalized = normalize(pred_embeddings, axis=1)

# Function to find top-N similar labels from your `animal_labels` embeddings
def get_top_similar_for_vector(input_vector, animal_vectors, animal_names, top_n=5):
    scores = []
    for idx, vec in enumerate(animal_vectors):
        sim = 1 - cosine(input_vector, vec)
        scores.append((animal_names[idx], sim))
    scores.sort(key=lambda x: x[1], reverse=True)
    return [name for name, _ in scores[:top_n]]

# Apply similarity search row-wise
top_5_results = []
top_10_results = []

for vec in pred_embeddings_normalized:
    top5 = get_top_similar_for_vector(vec, animal_embeddings_normalized, animal_labels, top_n=5)
    top10 = get_top_similar_for_vector(vec, animal_embeddings_normalized, animal_labels, top_n=10)
    top_5_results.append(", ".join(top5))
    top_10_results.append(", ".join(top10))

# Add similarity columns to the DataFrame
df['top_5_similar_animals'] = top_5_results
df['top_10_similar_animals'] = top_10_results

# Save or display the new DataFrame
df.to_csv("output_with_similarity.csv", index=False)
print("Processed DataFrame saved as 'output_with_similarity.csv'")
# Out:
# Processed DataFrame saved as 'output_with_similarity.csv'
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
from collections import defaultdict

# Initialize accuracy tracking
top5_correct = defaultdict(int)
top10_correct = defaultdict(int)
total_per_class = defaultdict(int)

# Loop over each row to compare image_label (actual) with top-5 and top-10 predictions
for _, row in df.iterrows():
    true_label = row['image_label'].replace("_", " ").strip()  # Normalize to match embedding format

    # Parse top-5 and top-10 predictions from the CSV columns
    top5_preds = [label.strip() for label in row['top_5_similar_animals'].split(',')]
    top10_preds = [label.strip() for label in row['top_10_similar_animals'].split(',')]

    total_per_class[true_label] += 1

    if true_label in top5_preds:
        top5_correct[true_label] += 1
    if true_label in top10_preds:
        top10_correct[true_label] += 1

# Compute accuracy per class
print("Top-5 Accuracy per Class:")
top5_acc = {}
for label in total_per_class:
    acc = top5_correct[label] / total_per_class[label]
    top5_acc[label] = acc
    print(f"  {label:<20}: {acc:.2f}")

print("\nTop-10 Accuracy per Class:")
top10_acc = {}
for label in total_per_class:
    acc = top10_correct[label] / total_per_class[label]
    top10_acc[label] = acc
    print(f"  {label:<20}: {acc:.2f}")

# Overall average accuracy
avg_top5 = sum(top5_correct.values()) / sum(total_per_class.values())
avg_top10 = sum(top10_correct.values()) / sum(total_per_class.values())

print(f"\nOverall Top-5 Accuracy:  {avg_top5:.2f}")
print(f"Overall Top-10 Accuracy: {avg_top10:.2f}")
# Out:
# Top-5 Accuracy per Class:
#   chimpanzee          : 0.80
#   giant panda         : 0.00
#   hippopotamus        : 0.00
#   humpback whale      : 1.00
#   leopard             : 1.00
#   persian cat         : 1.00
#   pig                 : 0.50
#   raccoon             : 0.40
#   rat                 : 1.00
#   seal                : 0.00
#
# Top-10 Accuracy per Class:
#   chimpanzee          : 0.80
#   giant panda         : 0.30
#   hippopotamus        : 0.30
#   humpback whale      : 1.00
#   leopard             : 1.00
#   persian cat         : 1.00
#   pig                 : 0.50
#   raccoon             : 0.80
#   rat                 : 1.00
#   seal                : 0.00
#
# Overall Top-5 Accuracy:  0.57
# Overall Top-10 Accuracy: 0.67

# %% [markdown]
# #final code to find similarity using Transformer#

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = "prediction_results_10images_per_class.csv"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "output_with_similarity_only_test_classes.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# ✅ Done! Saved to 'output_with_similarity_only_test_classes.csv'

# %% [markdown]
# #Final output for 10 images from each unseen class #
# #output_with_similarity_only_test_classes.csv--- Output file with transformer similarity result#
#
# # Visual Similarty is calculated based on hybrid feature approach#

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("output_with_similarity_only_test_classes.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("top5_accuracy_summary.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#       image_label  correct  total  top5_accuracy (%)
# 0      chimpanzee        8     10               80.0
# 1     giant panda        8     10               80.0
# 2    hippopotamus        3     10               30.0
# 3  humpback whale       10     10              100.0
# 4         leopard       10     10              100.0
# 5     persian cat       10     10              100.0
# 6             pig        8     10               80.0
# 7         raccoon        9     10               90.0
# 8             rat       10     10              100.0
# 9            seal        1     10               10.0
#
# Average Top-5 Accuracy: 77.00%

# %% [markdown]
# #Now checking the output for images of unseen classes#

# %%
import os
import glob
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Get class names from unseen folder structure (you can adjust path as needed)
image_class = [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]


# Index mapping (optional, not used directly here)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())  # Class names

# Encode class labels
embeddings = model.encode(words, convert_to_tensor=True)

# Path to your CSV file (update this path to your actual CSV file)
csv_file_path = r"/content/prediction_results_Resnet_GLCM_AWA2_seal"
df = pd.read_csv(csv_file_path)

# Clean pred_image_label column by removing underscores
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ', regex=False)

# Similarity processing
similar_wds = []

for _, row in df.iterrows():
    query_label = row['cleaned_pred_label']

    # Encode predicted label
    query_embedding = model.encode(query_label, convert_to_tensor=True)

    # Compute cosine similarity
    cosine_scores = util.cos_sim(query_embedding, embeddings)

    # Get top-5 most similar class names
    top_results = torch.topk(cosine_scores[0], k=5)

    top_labels = [words[idx] for idx in top_results.indices]
    top_scores = [round(float(cosine_scores[0][idx]) * 100, 2) for idx in top_results.indices]

    # Store as a tuple in a new column
    similar_wds.append((top_labels, top_scores))

# Add new column with results
df['top5_similar_labels_with_scores'] = similar_wds

# Save the updated CSV
output_csv_path = "prediction_results_Resnet_GLCM_AWA2_seal_output_with_similarity.csv"
df.to_csv(output_csv_path, index=False)
print(f"✅ Done! Saved to '{output_csv_path}'")
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# ✅ Done! Saved to 'prediction_results_Resnet_GLCM_AWA2_seal_output_with_similarity.csv'

# %%
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("prediction_results_Resnet_GLCM_AWA2_seal_output_with_similarity.csv")  # Change if needed

print(df.columns.tolist())


# Clean actual labels
df['image_label'] = df['image_label'].str.replace("_", " ").str.lower().str.strip()

# Parse top5 labels with scores
def extract_labels(top5_str):
    try:
        parsed = ast.literal_eval(top5_str)
        return [label.lower().strip() for label in parsed[0]]  # First part is labels
    except:
        return []

df['top_5_predicted'] = df['top5_similar_labels_with_scores'].apply(extract_labels)

# Compute hit (True if actual label is in top-5)
df['top5_hit'] = df.apply(lambda row: row['image_label'] in row['top_5_predicted'], axis=1)

# Compute per-class accuracy
accuracy_per_class = df.groupby('image_label')['top5_hit'].agg(['sum', 'count']).reset_index()
accuracy_per_class['top5_accuracy (%)'] = round((accuracy_per_class['sum'] / accuracy_per_class['count']) * 100, 2)
accuracy_per_class.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Average accuracy
average_top5_accuracy = round(accuracy_per_class['top5_accuracy (%)'].mean(), 2)

# Output
print("\nTop-5 Accuracy per Class:")
print(accuracy_per_class)

print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")

# Optional: Save
accuracy_per_class.to_csv("prediction_results_Resnet_GLCM_AWA2_seal_accuracy_summary.csv", index=False)
# Out:
# ['image_path', 'image_label', 'pred_image_label', 'act_label', 'pred_label', 'cleaned_pred_label', 'top5_similar_labels_with_scores']
#
# Top-5 Accuracy per Class:
#   image_label  correct  total  top5_accuracy (%)
# 0        seal       95    988               9.62
#
# Average Top-5 Accuracy: 9.62%

# %% [markdown]
# # Transfromer with Autoencoder#

# %%
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import normalize
from scipy.spatial.distance import cosine
import numpy as np

# Step 1: Load the model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Step 2: Define unseen class labels (from your image_class list)
image_class =  [
    "chimpanzee",
    "giant panda",
    "hippopotamus",
    "humpback whale",
    "leopard",
    "persian cat",
    "pig",
    "raccoon",
    "rat",
    "seal"
]

  # [
#     "polar bear", "blue whale", "bobcat", "cow", "dolphin", "gorilla", "killer whale", "lion",
#     "monkey", "mouse",
#     "ox",
#     "rabbit",
#     "rhinoceros",
#     "siamese cat",
#     "skunk",
#     "squirrel",
#     "tiger",#
#     "walrus",
#     "chimpanzee",
#     "giant panda",
#     "hippopotamus",
#     "humpback whale",
#     "leopard",
#     "persian cat",
#     "pig",
#     "raccoon",
#     "rat",
#     "seal"
# ]

  # [
#     "chimpanzee",
#     "giant panda",
#     "hippopotamus",
#     "humpback whale",
#     "leopard",
#     "persian cat",
#     "pig",
#     "raccoon",
#     "rat",
#     "seal"
# ]

# Step 3: Create index-to-class mapping (optional)
idx_to_unseen_class = {k: v for k, v in enumerate(image_class)}
words = list(idx_to_unseen_class.values())

# Step 4: Encode class labels as embeddings
embeddings_tensor = model.encode(words, convert_to_tensor=True)
embeddings_np = embeddings_tensor.cpu().numpy()  # Convert tensor to numpy for processing
class_embeddings_normalized = normalize(embeddings_np, axis=1)

# Step 5: Build index-to-vector mapping
label_index_to_vector = {
    idx: class_embeddings_normalized[idx]
    for idx in range(len(words))
}
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import os
from scipy.spatial.distance import cosine




def tune_autoencoder(input_dim, latent_dim):
    # Input layer
    input_layer = Input(shape=(input_dim,))

    # Sample Test 1
    # Encoder layers
    encoded = Dense(32, activation='relu')(input_layer)
    encoded = Dense(latent_dim, activation='relu')(encoded)

    # Decoder layers
    decoded = Dense(32, activation='relu')(encoded)
    decoded = Dense(input_dim, activation='sigmoid')(decoded)

    # Autoencoder model
    autoencoder = Model(input_layer, decoded)

    # Encoder model
    encoder = Model(input_layer, encoded)

    # Compile the autoencoder
    autoencoder.compile(optimizer='adam', loss='mse')
    # autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    return encoder, autoencoder

def find_similar_sentences(target_sentence_index, sentence_to_latent, top_n=10):
    target_latent = sentence_to_latent[target_sentence_index]
    similarities = []
    for index, latent in sentence_to_latent.items():
        if index != target_sentence_index:
            similarity = 1 - cosine(target_latent, latent)
            similarities.append((index, similarity))
    similarities.sort(key=lambda x: x[1], reverse=True)
    return similarities[:top_n]

def predict_with_autoencoder(input_word_index, sentence_to_latent, top_n=5):
    # Find sentences similar to the first sentence
    similar_sentences = find_similar_sentences(input_word_index, sentence_to_latent, top_n=top_n)
    similar_words = [custom_sentences[index] for index, score in similar_sentences]
    return similar_words

# %% [markdown]
# #modifieid aurocncoder model#

# %%
from keras.models import Model
from keras.layers import Input, Dense, Dropout

def tune_autoencoder(input_dim, latent_dim):
    # Input layer
    input_layer = Input(shape=(input_dim,))

    # Encoder
    encoded = Dense(64, activation='relu')(input_layer)
    encoded = Dropout(0.3)(encoded)  # Dropout added here
    encoded = Dense(32, activation='relu')(encoded)
    encoded = Dense(latent_dim, activation='relu')(encoded)

    # Decoder
    decoded = Dense(32, activation='relu')(encoded)
    decoded = Dropout(0.3)(decoded)  # Dropout added here
    decoded = Dense(64, activation='relu')(decoded)
    decoded = Dense(input_dim, activation='sigmoid')(decoded)

    # Autoencoder model
    autoencoder = Model(input_layer, decoded)

    # Encoder model
    encoder = Model(input_layer, encoded)

    # Compile the autoencoder
    autoencoder.compile(optimizer='adam', loss='mse')

    return encoder, autoencoder

# %%
encoder, autoencoder = tune_autoencoder(384, 16)
print("encoder summary : ")
encoder.summary()
print("autoencoder summary : ")
autoencoder.summary()
# Out:
# encoder summary :
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 384)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,248 (106.44 KB)
#  Trainable params: 27,248 (106.44 KB)
#  Non-trainable params: 0 (0.00 B)
# autoencoder summary :
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 384)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 384)            │        24,960 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,864 (214.31 KB)
#  Trainable params: 54,864 (214.31 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
 # Assume animal_embeddings_normalized is your training input
encoder, autoencoder = tune_autoencoder(input_dim=384, latent_dim=16)  # adjust dimensions as needed

autoencoder.fit(
    animal_embeddings_normalized,
    animal_embeddings_normalized,
    epochs=500,
    batch_size=32,
    shuffle=True,
    validation_split=0.1
    # callbacks=[early_stopping]
)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.2516 - val_loss: 0.2508
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.2512 - val_loss: 0.2504
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.2508 - val_loss: 0.2499
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.2504 - val_loss: 0.2494
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.2498 - val_loss: 0.2488
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.2493 - val_loss: 0.2481
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.2483 - val_loss: 0.2472
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2474 - val_loss: 0.2462
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.2464 - val_loss: 0.2450
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.2450 - val_loss: 0.2436
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2436 - val_loss: 0.2420
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.2425 - val_loss: 0.2401
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.2405 - val_loss: 0.2379
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.2369 - val_loss: 0.2354
# Epoch 15/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.2338 - val_loss: 0.2324
# Epoch 16/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.2314 - val_loss: 0.2290
# Epoch 17/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.2281 - val_loss: 0.2251
# Epoch 18/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.2247 - val_loss: 0.2207
# Epoch 19/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.2174 - val_loss: 0.2156
# Epoch 20/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2107 - val_loss: 0.2098
# Epoch 21/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.2045 - val_loss: 0.2034
# Epoch 22/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.1992 - val_loss: 0.1961
# Epoch 23/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.1954 - val_loss: 0.1881
# Epoch 24/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.1758 - val_loss: 0.1792
# Epoch 25/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.1710 - val_loss: 0.1694
# Epoch 26/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.1624 - val_loss: 0.1588
# Epoch 27/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.1412 - val_loss: 0.1472
# Epoch 28/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.1360 - val_loss: 0.1350
# Epoch 29/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.1232 - val_loss: 0.1222
# Epoch 30/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.1162 - val_loss: 0.1090
# Epoch 31/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0910 - val_loss: 0.0956
# Epoch 32/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0849 - val_loss: 0.0823
# Epoch 33/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0692 - val_loss: 0.0696
# Epoch 34/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0653 - val_loss: 0.0577
# Epoch 35/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0423 - val_loss: 0.0469
# Epoch 36/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0377 - val_loss: 0.0375
# Epoch 37/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0365 - val_loss: 0.0294
# Epoch 38/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0222 - val_loss: 0.0228
# Epoch 39/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0211 - val_loss: 0.0176
# Epoch 40/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0169 - val_loss: 0.0135
# Epoch 41/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 42/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 43/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0057 - val_loss: 0.0066
# Epoch 44/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0070 - val_loss: 0.0055
# Epoch 45/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0056 - val_loss: 0.0046
# Epoch 46/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 47/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 48/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 49/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 50/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 51/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 52/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 53/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 54/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 55/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 56/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 57/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 58/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 59/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 60/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 61/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 62/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 63/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 64/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 65/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 66/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 67/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 68/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 69/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 70/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 71/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 72/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 73/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 74/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 75/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 76/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 77/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 78/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 79/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 80/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 81/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 82/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 83/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 84/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 85/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 86/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 87/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 88/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0055 - val_loss: 0.0026
# Epoch 89/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 90/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 91/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 92/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 93/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 94/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 95/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 96/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 97/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 98/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 99/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 100/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 101/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 102/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 103/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 104/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 105/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 106/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 107/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 108/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 109/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 110/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 111/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 112/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 113/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 114/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 115/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 116/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 117/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 118/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 119/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 120/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 121/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 122/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 123/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 124/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 125/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 126/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 127/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 128/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 129/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 130/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 131/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 132/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 133/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 134/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 135/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 136/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 137/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 138/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 139/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 140/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 141/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 142/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 143/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 144/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 145/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 146/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 147/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 148/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 149/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 150/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 151/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 152/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 153/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 154/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 155/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 156/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 157/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 158/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 159/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 160/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 161/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 162/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 163/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 164/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 165/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 166/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 167/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 168/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 169/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 170/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 171/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 172/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 173/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 174/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 175/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 176/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 177/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 178/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 179/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 180/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 181/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 182/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 183/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 184/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 185/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 186/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 187/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 188/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 189/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 190/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 191/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 192/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 193/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 194/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 195/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 196/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 197/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 198/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 199/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 200/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 201/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 202/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 203/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 204/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 205/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 206/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 207/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 208/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 209/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 210/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 211/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 212/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 213/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 214/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 215/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 216/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 217/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 218/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 219/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 220/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 221/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 222/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 223/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 224/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 225/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 226/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 227/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 228/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 229/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 230/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 231/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 232/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 233/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 234/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 235/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 236/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 237/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 238/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 239/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 240/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 241/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 242/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 243/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 244/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 245/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 246/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 247/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 248/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 249/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 250/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 251/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 252/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 253/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 254/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 255/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 256/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 257/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 258/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 259/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 260/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 261/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 262/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 263/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 264/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 265/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 266/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 267/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 268/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 269/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 270/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 271/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 272/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 273/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 274/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 275/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 276/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 277/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 278/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 279/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 280/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 281/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 282/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 283/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 284/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 285/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 286/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 287/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 288/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 289/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 290/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 291/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 292/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 293/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 294/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 295/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 296/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 297/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 298/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 299/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 300/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 301/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 302/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 303/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 304/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 305/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 306/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 307/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 308/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 309/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 310/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 311/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 312/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 313/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 314/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 315/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 316/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 317/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 318/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 319/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 320/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 321/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 322/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 323/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 324/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 325/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 326/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 327/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 328/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 329/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 330/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 331/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0052 - val_loss: 0.0025
# Epoch 332/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 333/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 334/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 335/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 336/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 337/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 338/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 339/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 340/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 341/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 342/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 343/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 344/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 345/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 346/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 347/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 348/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 349/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 350/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 351/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 352/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 353/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 354/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 355/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 356/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 357/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 358/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 359/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 360/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 361/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 362/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 363/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 364/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 365/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 366/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 367/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 368/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 369/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 370/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 371/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 372/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 373/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 374/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 375/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 376/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 377/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 378/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 379/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 380/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 381/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 382/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 383/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 384/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 385/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 386/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 387/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 388/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 389/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 390/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 391/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 392/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 393/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 394/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 395/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 396/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 397/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 398/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 399/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 400/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 401/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 402/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 403/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 404/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 405/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 406/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 407/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 408/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 409/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 410/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 411/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 412/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 413/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 414/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 415/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 416/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 417/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 418/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 419/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 420/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 421/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 422/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 423/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 424/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 425/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 426/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 427/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 428/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 429/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 430/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 431/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 432/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 433/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 434/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 435/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 436/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 437/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 438/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 439/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 440/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 441/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 442/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 443/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 444/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 445/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 446/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 447/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 448/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 449/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 450/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 451/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 452/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 453/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 454/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 455/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 456/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 457/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 458/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 459/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 460/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 461/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 462/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 463/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 464/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 465/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 466/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 467/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 468/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 469/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 470/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 471/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 472/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 473/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 474/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 475/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 476/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 477/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 478/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 479/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 480/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 481/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 482/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 483/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 484/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 485/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 486/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 487/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 488/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 489/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 490/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 491/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 492/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 493/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 494/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 495/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 496/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 497/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 498/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 499/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 500/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0024 - val_loss: 0.0025

# %%
import matplotlib.pyplot as plt

# Define latent dimension if not already defined
latent_dim = 16  # Change to the actual value you used

# Plot training and validation loss
plt.plot(autoencoder.history.history['loss'], color='blue')
plt.plot(autoencoder.history.history['val_loss'], color='orange')
plt.title(f'Model Loss – Latent Dim {latent_dim}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

# Save and display
plt.savefig("autoencoder_loss_plot.png", bbox_inches='tight')
plt.show()

# %%
def predict_with_transformer(input_word, label_index_to_vector, label_list, transformer_model, top_n=10):
    """
    Predict top N most similar class labels to input_word based on cosine similarity.
    """
    input_embedding = transformer_model.encode([input_word], convert_to_numpy=True)
    input_embedding_normalized = input_embedding[0] / np.linalg.norm(input_embedding[0])

    similarities = []
    for idx, label_vector in label_index_to_vector.items():
        label = label_list[idx]
        if label.lower().replace('_', ' ') == input_word.lower().replace('_', ' '):
            continue  # Skip the input itself
        sim_score = 1 - cosine(input_embedding_normalized, label_vector)
        similarities.append((label, sim_score))

    top_similar = sorted(similarities, key=lambda x: x[1], reverse=True)[:top_n]
    return top_similar

# %%
predicted_class_label='gorilla'

# %%
predicted_class_label = 'gorilla'

if predicted_class_label in animal_labels:
    similar_words_transformer = predict_with_transformer(
        input_word=predicted_class_label,
        label_index_to_vector=label_index_to_vector,
        label_list=animal_labels,
        transformer_model=transformer_model,
        top_n=10
    )
    print(similar_words_transformer)
else:
    print(f"Label '{predicted_class_label}' not found in animal_labels.")
# Out:
# [('monkey', np.float32(0.6417081)), ('chimpanzee', np.float32(0.6233537)), ('lion', np.float32(0.51377547)), ('tiger', np.float32(0.5128764)), ('hippopotamus', np.float32(0.4889955)), ('squirrel', np.float32(0.46043557)), ('giant panda', np.float32(0.45725393)), ('dolphin', np.float32(0.43835765)), ('raccoon', np.float32(0.43780053)), ('cow', np.float32(0.42861867))]
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
import pandas as pd

# Load CSV
df = pd.read_csv('prediction_results_10images_per_class.csv')

# Clean underscores in predicted labels
df['cleaned_label'] = df['pred_image_label'].str.replace('_', ' ')

# Function to find top 10 similar labels
def get_top_similar_labels(label):
    if label not in animal_labels:
        return "Label not found"
    top_similar = predict_with_transformer(
        input_word=label,
        label_index_to_vector=label_index_to_vector,
        label_list=animal_labels,
        transformer_model=transformer_model,
        top_n=10
    )
    return ", ".join([lbl for lbl, _ in top_similar])

# Apply the function
df['top_10_similar_labels'] = df['cleaned_label'].apply(get_top_similar_labels)

# Save the result
df.to_csv('prediction_results_10images_per_class_with_similar_labels.csv', index=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
import pandas as pd
import ast
from collections import defaultdict

# Load your CSV
df = pd.read_csv('prediction_results_10images_per_class_with_similar_labels.csv')

# Clean labels (remove underscores and normalize to lowercase)
df['cleaned_gt_label'] = df['image_label'].str.replace('_', ' ').str.lower().str.strip()
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ').str.lower().str.strip()

# Safely parse top_10_similar_labels, even if stored as comma-separated strings
def safe_parse_list(cell):
    try:
        # Try literal eval if possible
        return ast.literal_eval(cell)
    except (ValueError, SyntaxError):
        # Fallback: split by commas if not a proper Python list
        return [item.strip().lower() for item in cell.split(',')] if isinstance(cell, str) else []

df['top_10_similar_labels'] = df['top_10_similar_labels'].apply(safe_parse_list)

# %%
# Initialize accuracy trackers
class_correct = defaultdict(int)
class_total = defaultdict(int)

# Compute per-class accuracy
for _, row in df.iterrows():
    gt_label = row['cleaned_gt_label']
    top_10 = [label.strip().lower() for label in row['top_10_similar_labels']]

    class_total[gt_label] += 1
    if gt_label in top_10:
        class_correct[gt_label] += 1

# Calculate per-class accuracy
class_accuracies = {
    label: class_correct[label] / class_total[label]
    for label in class_total
}

# Calculate average accuracy
average_accuracy = sum(class_accuracies.values()) / len(class_accuracies)

# Print results
print("Per-Class Accuracy:")
for label, acc in class_accuracies.items():
    print(f"{label:20s}: {acc:.2f}")

print(f"\nOverall Average Accuracy: {average_accuracy:.2f}")
# Out:
# Per-Class Accuracy:
# chimpanzee          : 0.80
# giant panda         : 0.30
# hippopotamus        : 0.30
# humpback whale      : 1.00
# leopard             : 1.00
# persian cat         : 1.00
# pig                 : 0.60
# raccoon             : 0.80
# rat                 : 1.00
# seal                : 0.00
#
# Overall Average Accuracy: 0.68

# %%
import pandas as pd

# Load CSV
df = pd.read_csv(r'/content/prediction_results_Resnet_GLCM_AWA2_seal')

# Clean underscores in predicted labels
df['cleaned_label'] = df['pred_image_label'].str.replace('_', ' ')

# Function to find top 10 similar labels
def get_top_similar_labels(label):
    if label not in animal_labels:
        return "Label not found"
    top_similar = predict_with_transformer(
        input_word=label,
        label_index_to_vector=label_index_to_vector,
        label_list=animal_labels,
        transformer_model=transformer_model,
        top_n=5
    )
    return ", ".join([lbl for lbl, _ in top_similar])

# Apply the function
df['top_10_similar_labels'] = df['cleaned_label'].apply(get_top_similar_labels)

# Save the result
df.to_csv('/content/prediction_results_Resnet_GLCM_AWA2_seal_with_autoencoder.csv', index=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
import pandas as pd
import ast
from collections import defaultdict

# Load your CSV
df = pd.read_csv('/content/prediction_results_Resnet_GLCM_AWA2_seal_with_autoencoder.csv')

# Clean labels (remove underscores and normalize to lowercase)
df['cleaned_gt_label'] = df['image_label'].str.replace('_', ' ').str.lower().str.strip()
df['cleaned_pred_label'] = df['pred_image_label'].str.replace('_', ' ').str.lower().str.strip()

# Safely parse top_10_similar_labels, even if stored as comma-separated strings
def safe_parse_list(cell):
    try:
        # Try literal eval if possible
        return ast.literal_eval(cell)
    except (ValueError, SyntaxError):
        # Fallback: split by commas if not a proper Python list
        return [item.strip().lower() for item in cell.split(',')] if isinstance(cell, str) else []

df['top_10_similar_labels'] = df['top_10_similar_labels'].apply(safe_parse_list)

# %%
# Initialize accuracy trackers
class_correct = defaultdict(int)
class_total = defaultdict(int)

# Compute per-class accuracy
for _, row in df.iterrows():
    gt_label = row['cleaned_gt_label']
    top_10 = [label.strip().lower() for label in row['top_10_similar_labels']]

    class_total[gt_label] += 1
    if gt_label in top_10:
        class_correct[gt_label] += 1

# Calculate per-class accuracy
class_accuracies = {
    label: class_correct[label] / class_total[label]
    for label in class_total
}

# Calculate average accuracy
average_accuracy = sum(class_accuracies.values()) / len(class_accuracies)

# Print results
print("Per-Class Accuracy:")
for label, acc in class_accuracies.items():
    print(f"{label:20s}: {acc:.2f}")

print(f"\nOverall Average Accuracy: {average_accuracy:.2f}")
# Out:
# Per-Class Accuracy:
# seal                : 0.00
#
# Overall Average Accuracy: 0.00

# %% [markdown]
# #Avarage Accuracy of AWA2 dataset with Autoecncoder#

# %%
import pandas as pd
import glob
import os

# Set your folder path where all 10 CSVs are located
csv_folder = r'/content/Top_5_summary'  # e.g., r'D:\ZSL\accuracy_csvs'

# Get all CSV file paths
csv_files = glob.glob(os.path.join(csv_folder, '*.csv'))

# Read and combine all CSVs into one DataFrame
df_list = [pd.read_csv(file) for file in csv_files]
combined_df = pd.concat(df_list, ignore_index=True)

# Display the combined summary
print("Combined Summary:")
print(combined_df.head(10))

# Save combined summary if needed
combined_df.to_csv('combined_accuracy_Transformer_summary_AWA2.csv', index=False)
# Out:
# Combined Summary:
#       image_label  correct  total  top5_accuracy (%)
# 0             pig      506    713              70.97
# 1            seal       95    988               9.62
# 2         leopard      719    720              99.86
# 3     persian cat      690    747              92.37
# 4      chimpanzee      675    728              92.72
# 5            seal       95    988               9.62
# 6     giant panda      822    874              94.05
# 7    hippopotamus      331    684              48.39
# 8         raccoon      424    512              82.81
# 9  humpback whale      709    709             100.00

# %%
# Drop rows where 'correct', 'total', or 'top5_accuracy (%)' are NaN
cleaned_df = combined_df.dropna(subset=['correct', 'total', 'top5_accuracy (%)'])

# Convert columns to numeric if not already
cleaned_df['correct'] = pd.to_numeric(cleaned_df['correct'])
cleaned_df['total'] = pd.to_numeric(cleaned_df['total'])
cleaned_df['top5_accuracy (%)'] = pd.to_numeric(cleaned_df['top5_accuracy (%)'])

# Display cleaned summary
print("Cleaned Combined Summary:")
print(cleaned_df)
# Out:
# Cleaned Combined Summary:
#       image_label  correct  total  top5_accuracy (%)
# 0             pig      506    713              70.97
# 1            seal       95    988               9.62
# 2         leopard      719    720              99.86
# 3     persian cat      690    747              92.37
# 4      chimpanzee      675    728              92.72
# 5            seal       95    988               9.62
# 6     giant panda      822    874              94.05
# 7    hippopotamus      331    684              48.39
# 8         raccoon      424    512              82.81
# 9  humpback whale      709    709             100.00

# %%
average_top5_accuracy = combined_df['top5_accuracy (%)'].mean()
print(f"\nAverage Top-5 Accuracy: {average_top5_accuracy:.2f}%")
# Out:
# Average Top-5 Accuracy: 70.04%

# %%
import pandas as pd
import ast
from collections import defaultdict

# Load your CSV
df = pd.read_csv('updated_with_similar_labels.csv')

# Clean image labels (remove underscores, lowercase, strip)
df['cleaned_gt_label'] = df['image_label'].str.replace('_', ' ').str.lower().str.strip()

# Ensure top_10_similar_labels is a proper list of cleaned strings
def safe_parse_and_clean(cell):
    try:
        parsed = ast.literal_eval(cell)
    except (ValueError, SyntaxError):
        parsed = cell.split(',') if isinstance(cell, str) else []

    # Clean each label: remove underscores, lowercase, strip
    return [str(label).replace('_', ' ').lower().strip() for label in parsed]

df['top_10_similar_labels'] = df['top_10_similar_labels'].apply(safe_parse_and_clean)

# Initialize accuracy trackers
class_correct = defaultdict(int)
class_total = defaultdict(int)

# Compute per-class accuracy
for _, row in df.iterrows():
    gt_label = row['cleaned_gt_label']
    top_10 = row['top_10_similar_labels']

    class_total[gt_label] += 1
    if gt_label in top_10:
        class_correct[gt_label] += 1

# Calculate per-class accuracy
class_accuracies = {
    label: class_correct[label] / class_total[label]
    for label in class_total
}

# Calculate average accuracy
average_accuracy = sum(class_accuracies.values()) / len(class_accuracies)

# Print results
print("Per-Class Accuracy:")
for label, acc in class_accuracies.items():
    print(f"{label:20s}: {acc:.2f}")

print(f"\nOverall Average Accuracy: {average_accuracy:.2f}")
# Out:
# Per-Class Accuracy:
# chimpanzee          : 0.80
# giant panda         : 0.80
# hippopotamus        : 0.00
# humpback whale      : 1.00
# leopard             : 0.20
# persian cat         : 1.00
# pig                 : 0.80
# raccoon             : 0.40
# rat                 : 1.00
# seal                : 0.10
#
# Overall Average Accuracy: 0.61
